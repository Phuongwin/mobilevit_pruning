# %% [markdown]
# # MobileViT Pruning

# %% [markdown]
# ## Import Libraries

# %%
# !pip install einops
# !mkdir visualizations
# Out:
# Collecting einops
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Installing collected packages: einops
# Successfully installed einops-0.4.1

# %%
import time
import matplotlib.pyplot as plt
import seaborn as sns
from einops import rearrange

import torch
import torch.nn as nn 
import torch.optim as optim
from torch.nn.utils import prune

import torchvision
from torchvision.transforms.transforms import RandomHorizontalFlip
from torchvision import datasets, transforms

# %%
def conv_1x1_bn(inp, oup):
    return nn.Sequential(
        nn.Conv2d(inp, oup, 1, 1, 0, bias=False),
        nn.BatchNorm2d(oup),
        nn.SiLU()
    )


def conv_nxn_bn(inp, oup, kernal_size=3, stride=1):
    return nn.Sequential(
        nn.Conv2d(inp, oup, kernal_size, stride, 1, bias=False),
        nn.BatchNorm2d(oup),
        nn.SiLU()
    )


class PreNorm(nn.Module):
    def __init__(self, dim, fn):
        super().__init__()
        self.norm = nn.LayerNorm(dim)
        self.fn = fn
    
    def forward(self, x, **kwargs):
        return self.fn(self.norm(x), **kwargs)


class FeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, dropout=0.):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, hidden_dim),
            nn.SiLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, dim),
            nn.Dropout(dropout)
        )
    
    def forward(self, x):
        return self.net(x)


class Attention(nn.Module):
    def __init__(self, dim, heads=8, dim_head=64, dropout=0.):
        super().__init__()
        inner_dim = dim_head *  heads
        project_out = not (heads == 1 and dim_head == dim)

        self.heads = heads
        self.scale = dim_head ** -0.5

        self.attend = nn.Softmax(dim = -1)
        self.to_qkv = nn.Linear(dim, inner_dim * 3, bias = False)

        self.to_out = nn.Sequential(
            nn.Linear(inner_dim, dim),
            nn.Dropout(dropout)
        ) if project_out else nn.Identity()

    def forward(self, x):
        qkv = self.to_qkv(x).chunk(3, dim=-1)
        q, k, v = map(lambda t: rearrange(t, 'b p n (h d) -> b p h n d', h = self.heads), qkv)

        dots = torch.matmul(q, k.transpose(-1, -2)) * self.scale
        attn = self.attend(dots)
        out = torch.matmul(attn, v)
        out = rearrange(out, 'b p h n d -> b p n (h d)')
        return self.to_out(out)


class Transformer(nn.Module):
    def __init__(self, dim, depth, heads, dim_head, mlp_dim, dropout=0.):
        super().__init__()
        self.layers = nn.ModuleList([])
        for _ in range(depth):
            self.layers.append(nn.ModuleList([
                PreNorm(dim, Attention(dim, heads, dim_head, dropout)),
                PreNorm(dim, FeedForward(dim, mlp_dim, dropout))
            ]))
    
    def forward(self, x):
        for attn, ff in self.layers:
            x = attn(x) + x
            x = ff(x) + x
        return x


class MV2Block(nn.Module):
    def __init__(self, inp, oup, stride=1, expansion=4):
        super().__init__()
        self.stride = stride
        assert stride in [1, 2]

        hidden_dim = int(inp * expansion)
        self.use_res_connect = self.stride == 1 and inp == oup

        if expansion == 1:
            self.conv = nn.Sequential(
                # dw
                nn.Conv2d(hidden_dim, hidden_dim, 3, stride, 1, groups=hidden_dim, bias=False),
                nn.BatchNorm2d(hidden_dim),
                nn.SiLU(),
                # pw-linear
                nn.Conv2d(hidden_dim, oup, 1, 1, 0, bias=False),
                nn.BatchNorm2d(oup),
            )
        else:
            self.conv = nn.Sequential(
                # pw
                nn.Conv2d(inp, hidden_dim, 1, 1, 0, bias=False),
                nn.BatchNorm2d(hidden_dim),
                nn.SiLU(),
                # dw
                nn.Conv2d(hidden_dim, hidden_dim, 3, stride, 1, groups=hidden_dim, bias=False),
                nn.BatchNorm2d(hidden_dim),
                nn.SiLU(),
                # pw-linear
                nn.Conv2d(hidden_dim, oup, 1, 1, 0, bias=False),
                nn.BatchNorm2d(oup),
            )

    def forward(self, x):
        if self.use_res_connect:
            return x + self.conv(x)
        else:
            return self.conv(x)


class MobileViTBlock(nn.Module):
    def __init__(self, dim, depth, channel, kernel_size, patch_size, mlp_dim, dropout=0.):
        super().__init__()
        self.ph, self.pw = patch_size

        self.conv1 = conv_nxn_bn(channel, channel, kernel_size)
        self.conv2 = conv_1x1_bn(channel, dim)

        self.transformer = Transformer(dim, depth, 4, 8, mlp_dim, dropout)

        self.conv3 = conv_1x1_bn(dim, channel)
        self.conv4 = conv_nxn_bn(2 * channel, channel, kernel_size)
    
    def forward(self, x):
        y = x.clone()

        # Local representations
        x = self.conv1(x)
        x = self.conv2(x)
        
        # Global representations
        _, _, h, w = x.shape
        x = rearrange(x, 'b d (h ph) (w pw) -> b (ph pw) (h w) d', ph=self.ph, pw=self.pw)
        x = self.transformer(x)
        x = rearrange(x, 'b (ph pw) (h w) d -> b d (h ph) (w pw)', h=h//self.ph, w=w//self.pw, ph=self.ph, pw=self.pw)

        # Fusion
        x = self.conv3(x)
        x = torch.cat((x, y), 1)
        x = self.conv4(x)
        return x


class MobileViT(nn.Module):
    def __init__(self, image_size, dims, channels, num_classes, expansion=4, kernel_size=3, patch_size=(2, 2)):
        super().__init__()
        ih, iw = image_size
        ph, pw = patch_size
        assert ih % ph == 0 and iw % pw == 0

        L = [2, 4, 3]

        self.conv1 = conv_nxn_bn(3, channels[0], stride=2)

        self.mv2 = nn.ModuleList([])
        self.mv2.append(MV2Block(channels[0], channels[1], 1, expansion))
        self.mv2.append(MV2Block(channels[1], channels[2], 2, expansion))
        self.mv2.append(MV2Block(channels[2], channels[3], 1, expansion))
        self.mv2.append(MV2Block(channels[2], channels[3], 1, expansion))   # Repeat
        self.mv2.append(MV2Block(channels[3], channels[4], 2, expansion))
        self.mv2.append(MV2Block(channels[5], channels[6], 2, expansion))
        self.mv2.append(MV2Block(channels[7], channels[8], 2, expansion))
        
        self.mvit = nn.ModuleList([])
        self.mvit.append(MobileViTBlock(dims[0], L[0], channels[5], kernel_size, patch_size, int(dims[0]*2)))
        self.mvit.append(MobileViTBlock(dims[1], L[1], channels[7], kernel_size, patch_size, int(dims[1]*4)))
        self.mvit.append(MobileViTBlock(dims[2], L[2], channels[9], kernel_size, patch_size, int(dims[2]*4)))

        self.conv2 = conv_1x1_bn(channels[-2], channels[-1])

        self.pool = nn.AvgPool2d(ih//32, 1)
        self.fc = nn.Linear(channels[-1], num_classes, bias=False)

    def forward(self, x):
        x = self.conv1(x)
        x = self.mv2[0](x)

        x = self.mv2[1](x)
        x = self.mv2[2](x)
        x = self.mv2[3](x)      # Repeat

        x = self.mv2[4](x)
        x = self.mvit[0](x)

        x = self.mv2[5](x)
        x = self.mvit[1](x)

        x = self.mv2[6](x)
        x = self.mvit[2](x)
        x = self.conv2(x)

        x = self.pool(x).view(-1, x.shape[1])
        x = self.fc(x)
        return x

# %% [markdown]
# ### Helper Functions

# %%
def mobilevit_xxs():
    dims = [64, 80, 96]
    channels = [16, 16, 24, 24, 48, 48, 64, 64, 80, 80, 320]
    return MobileViT((64, 64), dims, channels, num_classes=10, expansion=2)

def mobilevit_xs():
    dims = [96, 120, 144]
    channels = [16, 32, 48, 48, 64, 64, 80, 80, 96, 96, 384]
    return MobileViT((64, 64), dims, channels, num_classes=10)

def mobilevit_s():
    dims = [144, 192, 240]
    channels = [16, 32, 64, 64, 96, 96, 128, 128, 160, 160, 640]
    return MobileViT((64, 64), dims, channels, num_classes=10)

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
def train_valid_split(dataset, train_percentage: float = 0.8):
    
    dataset_size = dataset.__len__()

    train_count = int(dataset_size  * train_percentage)
    valid_count = dataset_size - train_count

    train_set, valid_set = torch.utils.data.random_split(dataset, [train_count, valid_count])

    print(f'Train Set: {train_set.__len__()}')
    print(f'Validation Set: {valid_set.__len__()}')
    print(f"Total: {train_set.__len__() + valid_set.__len__()}")

    return train_set, valid_set

# %%
standard_transform = transforms.Compose([
                            transforms.Resize(64),
                            transforms.RandomHorizontalFlip(0.5),
                            transforms.ToTensor(),
                            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                 std=[0.229, 0.224, 0.225])
                            ])

test_transform = transforms.Compose([
                            transforms.Resize(64),
                            transforms.ToTensor(),
                            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                 std=[0.229, 0.224, 0.225])
                            ])

# %%
def plot_nonzero_accuracy(global_param, global_acc, struct_param, struct_acc, unstruct_param, unstruct_acc, model_size):
  plt.figure(figsize=(10,10))
  plt.plot(global_param, global_acc, color='blue', label='Global Pruning')
  plt.plot(struct_param, struct_acc, color='magenta', label='Structured Pruning')
  plt.plot(unstruct_param, unstruct_acc, color='green', label='Unstructured Pruning')
  plt.xlabel('# nonzero parameters')
  plt.ylabel('Accuracy (%)')
  plt.legend()
  plt.ylim([0, 100])
  plt.title(f'{model_size.upper()} MobileViT Pruning')
  plt.savefig(f'visualizations/pruning_techniques_param_acc.png', dpi=300)

def plot_train_validation(count, train_plot, valid_plot, model_size, dataset_name, type):
  plt.figure(figsize=(10,10))
  plt.plot(count, train_plot, color='blue', label='Train')
  plt.plot(count, valid_plot, color='magenta', label='Validation')
  plt.xlabel('Epochs')
  if type == 'Accuracy':
      plt.ylabel('Accuracy (%)')
  else:
      plt.ylabel('Loss')
  plt.legend()
  if type == 'Accuracy':
      plt.ylim([0, 100])
  plt.title(f'{model_size.upper()} MobileViT Training/Validation {type} - {dataset_name.upper()}')
  plt.savefig(f'visualizations/{model_size}_{dataset_name.lower()}_{type.lower()}.png', dpi=300)

# %%
'''
Structured Pruning - Pruning a larger part of the network (channel or layer)
    - filter pruning
'''
def prune_model_ln_structured(model, proportion = 0.5):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            prune.ln_structured(module, 'weight', proportion, n=1, dim=1)
            prune.remove(module, 'weight')
        elif isinstance(module, nn.Linear):
            prune.ln_structured(module, 'weight', proportion, n=1, dim=1)
            prune.remove(module, 'weight')
    return model

'''
Unstructured Pruning - Find less salient connections and remove them
    - weight pruning
'''
def prune_model_l1_unstructured(model, proportion = 0.5):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            prune.l1_unstructured(module, 'weight', proportion)
            prune.remove(module, 'weight')
        elif isinstance(module, nn.Linear):
            if module.bias is not None:
                prune.l1_unstructured(module, 'bias', proportion)
                prune.remove(module, 'bias')

            prune.l1_unstructured(module, 'weight', proportion)
            prune.remove(module, 'weight')

    return model

'''
Global Unstructured Pruning - removing across the whole model
    - Global Structured wouldn't make sense as a technique
'''
def prune_model_global_unstructured(model, proportion = .5):
    parameters_to_prune = []
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            parameters_to_prune.append((module, 'weight'))
        elif isinstance(module, nn.Linear):
            parameters_to_prune.append((module, 'weight'))
    
    prune.global_unstructured(parameters_to_prune, 
                              pruning_method = prune.L1Unstructured,
                              amount = proportion)

    for module, _ in parameters_to_prune:
        prune.remove(module, 'weight')
    return model

'''
Sparsity = 1 - (count_nonzero(model)/total_elements(model))
'''
def sparsity_calculation(model):
    total_zeros = 0
    total_nonzeros = 0
    total_param = 0
    for i in list(model.state_dict().values()):
        zeros = torch.sum(i == 0)
        non_zeros = torch.count_nonzero(i)
        total_zeros += int(zeros)
        total_nonzeros += int(non_zeros)
        total_param += int(non_zeros + zeros)

    sparsity = round(1 - float(total_nonzeros/total_param), 4)
    print(f"Non-Zero Parameters: {total_nonzeros}")
    print(f"Total Parameters: {total_param}")
    print(f"Sparsity: {sparsity}")
    
    return total_nonzeros

'''
Model Testing
'''
def test_model(model, test_loader):
    with torch.no_grad():
        test_correct = 0
        test_total = 0
        for i, data in enumerate(test_loader):
            images, labels = data
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)

            _, predicted = torch.max(outputs.data, 1)
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()
    return (100 * test_correct // test_total), test_total

# %% [markdown]
# ### Configurations

# %%
BATCH_SIZE = 128
N_EPOCH = 50
LEARNING_RATE = 0.001

dataset_name = 'cifar10'
model_size = 's'
training_set_allocation = 0.8

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

unpruned_path = f"./unpruned_{model_size}_weights_{device}_{dataset_name}.pth"

print(unpruned_path)
# Out:
# ./unpruned_s_weights_cuda_cifar10.pth

# %% [markdown]
# ### Loading Dataset

# %%
if dataset_name == 'cifar10':
  print('Cifar10 Dataset Selected')
  dataset_train = datasets.CIFAR10('./data/cifar10', train=True, download=True, transform=standard_transform)
  dataset_test = datasets.CIFAR10('./data/cifar10', train=False, download=True, transform=test_transform)
elif dataset_name == 'cifar100':
  print('Cifar100 Dataset Selected')
  dataset_train = datasets.CIFAR100('./data/cifar100', train=True, download=True, transform=standard_transform)
  dataset_test = datasets.CIFAR100('./data/cifar100', train=False, download=True, transform=test_transform)
# Out:
# Cifar10 Dataset Selected
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar10/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar10/cifar-10-python.tar.gz to ./data/cifar10
# Files already downloaded and verified

# %%
train_set, valid_set = train_valid_split(dataset_train, training_set_allocation)
print(f'Test Set: {dataset_test.__len__()}')
# Out:
# Train Set: 40000
# Validation Set: 10000
# Total: 50000
# Test Set: 10000

# %% [markdown]
# ### Create DataLoaders

# %%
train_loader = torch.utils.data.DataLoader(train_set,
                                           batch_size = BATCH_SIZE,
                                           num_workers = 2,
                                           drop_last = True,
                                           shuffle = True
                                          )

valid_loader = torch.utils.data.DataLoader(valid_set,
                                           batch_size = BATCH_SIZE,
                                           num_workers = 2,
                                           drop_last = True,
                                           shuffle = True
                                          )

test_loader = torch.utils.data.DataLoader(dataset_test,
                                          batch_size = BATCH_SIZE,
                                          num_workers = 2,
                                          drop_last = True,
                                          shuffle = True
                                         )

# %% [markdown]
# ### Model Instantiation

# %%
if model_size == 'xs': 
  model = mobilevit_xs()
elif model_size == 'xxs': 
  model = mobilevit_xxs()
else:
  if model_size != 's':
    print('Model Size does not exist - Default selected')
    model_size = 's'
  model = mobilevit_s()

model = model.to(device)    # Decide between GPU and CPU
print(f'MobileViT {model_size} on {device}: {count_parameters(model)} parameters')
# Out:
# MobileViT s on cuda: 5003120 parameters

# %% [markdown]
# # Training

# %%
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = optim.AdamW(model.parameters(), lr = LEARNING_RATE)

### Define Lists for visualizations
train_loss_plot = []
train_acc_plot = []
valid_loss_plot = []
valid_acc_plot = []

print("Begin Training")
best_accuracy = 0

t1 = time.perf_counter()
for epoch in range(N_EPOCH):
  print(f"Epoch {epoch+1}")

  train_loss = 0.0
  train_correct = 0
  train_total = 0
  model.train()
  for i, data in enumerate(train_loader, 0):
    inputs, labels = data
    inputs, labels = inputs.to(device), labels.to(device)

    optimizer.zero_grad()

    outputs = model(inputs)

    _, predicted = torch.max(outputs.data, 1)

    loss = criterion(outputs, labels)

    train_total += labels.size(0)
    train_correct += (predicted == labels).sum().item()
    loss.backward()
    optimizer.step()

    train_loss += loss.item()

  valid_loss = 0.0
  valid_correct = 0
  valid_total = 0
  model.eval()
  for i, data in enumerate(valid_loader, 0):
    inputs, labels = data
    inputs, labels = inputs.to(device), labels.to(device)

    outputs = model(inputs)

    _, predicted = torch.max(outputs.data, 1)

    loss = criterion(outputs, labels)

    valid_total += labels.size(0)
    valid_correct += (predicted == labels).sum().item()
    valid_loss += loss.item()

  print(f'Epoch {epoch + 1} \t Training Loss:   {(train_loss / len(train_loader)):.4f} \
                              Training Acc:    {(train_correct / train_total):.4f}')
  print(f'Epoch {epoch + 1} \t Validation Loss: {(valid_loss / len(valid_loader)):.4f} \
                              Validation Acc:  {(valid_correct / valid_total):.4f}')
    
  train_loss_plot.append(round(train_loss / len(train_loader), 4))
  train_acc_plot.append(round(100 * (train_correct / train_total), 4))
  valid_loss_plot.append(round(valid_loss / len(valid_loader), 4))
  valid_acc_plot.append(round(100 * (valid_correct / valid_total), 4))

  current_accuracy = 100 * (valid_correct / valid_total)
  if current_accuracy > best_accuracy:
    print("Saved better model")
    best_accuracy = current_accuracy
    torch.save(model.state_dict(), unpruned_path)
  else:
    print("Not saved")
        
t2 = time.perf_counter()

print(f"Finished Training in {int(t2 - t1)} seconds")

torch.save(model.state_dict(), unpruned_path)

epoch_count = range(1, N_EPOCH + 1)
plot_train_validation(epoch_count, train_acc_plot, valid_acc_plot, model_size, dataset_name ,'Accuracy')
plot_train_validation(epoch_count, train_loss_plot, valid_loss_plot, model_size, dataset_name, 'Loss')
# Out:
# Begin Training
# Epoch 1
# Epoch 1 	 Training Loss:   1.5702                               Training Acc:    0.4995
# Epoch 1 	 Validation Loss: 1.4264                               Validation Acc:  0.5955
# Saved better model
# Epoch 2
# Epoch 2 	 Training Loss:   1.2182                               Training Acc:    0.6746
# Epoch 2 	 Validation Loss: 1.1244                               Validation Acc:  0.7234
# Saved better model
# Epoch 3
# Epoch 3 	 Training Loss:   1.0639                               Training Acc:    0.7496
# Epoch 3 	 Validation Loss: 1.0494                               Validation Acc:  0.7552
# Saved better model
# Epoch 4
# Epoch 4 	 Training Loss:   0.9781                               Training Acc:    0.7890
# Epoch 4 	 Validation Loss: 0.9907                               Validation Acc:  0.7831
# Saved better model
# Epoch 5
# Epoch 5 	 Training Loss:   0.9164                               Training Acc:    0.8191
# Epoch 5 	 Validation Loss: 0.9804                               Validation Acc:  0.7910
# Saved better model
# Epoch 6
# Epoch 6 	 Training Loss:   1.1611                               Training Acc:    0.7063
# Epoch 6 	 Validation Loss: 1.2707                               Validation Acc:  0.6553
# Not saved
# Epoch 7
# Epoch 7 	 Training Loss:   1.0591                               Training Acc:    0.7498
# Epoch 7 	 Validation Loss: 0.9940                               Validation Acc:  0.7774
# Not saved
# Epoch 8
# Epoch 8 	 Training Loss:   0.9227                               Training Acc:    0.8151
# Epoch 8 	 Validation Loss: 0.9613                               Validation Acc:  0.7957
# Saved better model
# Epoch 9
# Epoch 9 	 Training Loss:   0.9572                               Training Acc:    0.7988
# Epoch 9 	 Validation Loss: 1.2359                               Validation Acc:  0.6730
# Not saved
# Epoch 10
# Epoch 10 	 Training Loss:   0.9174                               Training Acc:    0.8177
# Epoch 10 	 Validation Loss: 0.9246                               Validation Acc:  0.8114
# Saved better model
# Epoch 11
# Epoch 11 	 Training Loss:   0.8251                               Training Acc:    0.8597
# Epoch 11 	 Validation Loss: 0.9168                               Validation Acc:  0.8172
# Saved better model
# Epoch 12
# Epoch 12 	 Training Loss:   0.7920                               Training Acc:    0.8756
# Epoch 12 	 Validation Loss: 0.8829                               Validation Acc:  0.8327
# Saved better model
# Epoch 13
# Epoch 13 	 Training Loss:   0.7652                               Training Acc:    0.8877
# Epoch 13 	 Validation Loss: 0.8915                               Validation Acc:  0.8279
# Not saved
# Epoch 14
# Epoch 14 	 Training Loss:   0.7383                               Training Acc:    0.8993
# Epoch 14 	 Validation Loss: 0.8963                               Validation Acc:  0.8316
# Not saved
# Epoch 15
# Epoch 15 	 Training Loss:   0.7244                               Training Acc:    0.9058
# Epoch 15 	 Validation Loss: 0.9032                               Validation Acc:  0.8295
# Not saved
# Epoch 16
# Epoch 16 	 Training Loss:   0.7065                               Training Acc:    0.9144
# Epoch 16 	 Validation Loss: 0.9089                               Validation Acc:  0.8297
# Not saved
# Epoch 17
# Epoch 17 	 Training Loss:   0.6937                               Training Acc:    0.9187
# Epoch 17 	 Validation Loss: 0.9067                               Validation Acc:  0.8287
# Not saved
# Epoch 18
# Epoch 18 	 Training Loss:   0.6934                               Training Acc:    0.9195
# Epoch 18 	 Validation Loss: 0.9167                               Validation Acc:  0.8253
# Not saved
# Epoch 19
# Epoch 19 	 Training Loss:   0.7257                               Training Acc:    0.9048
# Epoch 19 	 Validation Loss: 1.3541                               Validation Acc:  0.6408
# Not saved
# Epoch 20
# Epoch 20 	 Training Loss:   0.9533                               Training Acc:    0.8004
# Epoch 20 	 Validation Loss: 1.0823                               Validation Acc:  0.7478
# Not saved
# Epoch 21
# Epoch 21 	 Training Loss:   0.8287                               Training Acc:    0.8554
# Epoch 21 	 Validation Loss: 0.9372                               Validation Acc:  0.8115
# Not saved
# Epoch 22
# Epoch 22 	 Training Loss:   0.7430                               Training Acc:    0.8947
# Epoch 22 	 Validation Loss: 0.8986                               Validation Acc:  0.8282
# Not saved
# Epoch 23
# Epoch 23 	 Training Loss:   0.6849                               Training Acc:    0.9233
# Epoch 23 	 Validation Loss: 0.8809                               Validation Acc:  0.8395
# Saved better model
# Epoch 24
# Epoch 24 	 Training Loss:   0.6579                               Training Acc:    0.9336
# Epoch 24 	 Validation Loss: 0.8913                               Validation Acc:  0.8374
# Not saved
# Epoch 25
# Epoch 25 	 Training Loss:   0.6532                               Training Acc:    0.9351
# Epoch 25 	 Validation Loss: 0.8828                               Validation Acc:  0.8395
# Not saved
# Epoch 26
# Epoch 26 	 Training Loss:   0.6363                               Training Acc:    0.9444
# Epoch 26 	 Validation Loss: 0.8919                               Validation Acc:  0.8416
# Saved better model
# Epoch 27
# Epoch 27 	 Training Loss:   0.6146                               Training Acc:    0.9526
# Epoch 27 	 Validation Loss: 0.8918                               Validation Acc:  0.8469
# Saved better model
# Epoch 28
# Epoch 28 	 Training Loss:   0.6293                               Training Acc:    0.9465
# Epoch 28 	 Validation Loss: 0.9257                               Validation Acc:  0.8310
# Not saved
# Epoch 29
# Epoch 29 	 Training Loss:   0.6436                               Training Acc:    0.9387
# Epoch 29 	 Validation Loss: 1.0211                               Validation Acc:  0.7894
# Not saved
# Epoch 30
# Epoch 30 	 Training Loss:   0.8273                               Training Acc:    0.8553
# Epoch 30 	 Validation Loss: 0.9043                               Validation Acc:  0.8264
# Not saved
# Epoch 31
# Epoch 31 	 Training Loss:   0.6839                               Training Acc:    0.9212
# Epoch 31 	 Validation Loss: 0.8865                               Validation Acc:  0.8421
# Not saved
# Epoch 32
# Epoch 32 	 Training Loss:   0.7189                               Training Acc:    0.9062
# Epoch 32 	 Validation Loss: 0.8912                               Validation Acc:  0.8319
# Not saved
# Epoch 33
# Epoch 33 	 Training Loss:   0.6545                               Training Acc:    0.9340
# Epoch 33 	 Validation Loss: 0.8989                               Validation Acc:  0.8390
# Not saved
# Epoch 34
# Epoch 34 	 Training Loss:   0.6177                               Training Acc:    0.9500
# Epoch 34 	 Validation Loss: 0.9302                               Validation Acc:  0.8303
# Not saved
# Epoch 35
# Epoch 35 	 Training Loss:   0.6296                               Training Acc:    0.9460
# Epoch 35 	 Validation Loss: 1.0575                               Validation Acc:  0.7741
# Not saved
# Epoch 36
# Epoch 36 	 Training Loss:   0.6619                               Training Acc:    0.9315
# Epoch 36 	 Validation Loss: 0.8937                               Validation Acc:  0.8444
# Not saved
# Epoch 37
# Epoch 37 	 Training Loss:   0.5915                               Training Acc:    0.9623
# Epoch 37 	 Validation Loss: 0.9011                               Validation Acc:  0.8439
# Not saved
# Epoch 38
# Epoch 38 	 Training Loss:   0.5824                               Training Acc:    0.9671
# Epoch 38 	 Validation Loss: 0.9909                               Validation Acc:  0.8120
# Not saved
# Epoch 39
# Epoch 39 	 Training Loss:   0.7693                               Training Acc:    0.8833
# Epoch 39 	 Validation Loss: 0.9737                               Validation Acc:  0.7977
# Not saved
# Epoch 40
# Epoch 40 	 Training Loss:   0.7672                               Training Acc:    0.8824
# Epoch 40 	 Validation Loss: 0.9887                               Validation Acc:  0.7978
# Not saved
# Epoch 41
# Epoch 41 	 Training Loss:   0.6642                               Training Acc:    0.9295
# Epoch 41 	 Validation Loss: 0.9003                               Validation Acc:  0.8360
# Not saved
# Epoch 42
# Epoch 42 	 Training Loss:   0.6048                               Training Acc:    0.9554
# Epoch 42 	 Validation Loss: 0.8943                               Validation Acc:  0.8481
# Saved better model
# Epoch 43
# Epoch 43 	 Training Loss:   0.7245                               Training Acc:    0.9053
# Epoch 43 	 Validation Loss: 1.2111                               Validation Acc:  0.6907
# Not saved
# Epoch 44
# Epoch 44 	 Training Loss:   0.7748                               Training Acc:    0.8793
# Epoch 44 	 Validation Loss: 0.8955                               Validation Acc:  0.8379
# Not saved
# Epoch 45
# Epoch 45 	 Training Loss:   0.8234                               Training Acc:    0.8566
# Epoch 45 	 Validation Loss: 0.9697                               Validation Acc:  0.7981
# Not saved
# Epoch 46
# Epoch 46 	 Training Loss:   0.8016                               Training Acc:    0.8663
# Epoch 46 	 Validation Loss: 1.0167                               Validation Acc:  0.7747
# Not saved
# Epoch 47
# Epoch 47 	 Training Loss:   0.7424                               Training Acc:    0.8937
# Epoch 47 	 Validation Loss: 0.9186                               Validation Acc:  0.8242
# Not saved
# Epoch 48
# Epoch 48 	 Training Loss:   0.6713                               Training Acc:    0.9256
# Epoch 48 	 Validation Loss: 0.9216                               Validation Acc:  0.8293
# Not saved
# Epoch 49
# Epoch 49 	 Training Loss:   0.6607                               Training Acc:    0.9299
# Epoch 49 	 Validation Loss: 0.9132                               Validation Acc:  0.8353
# Not saved
# Epoch 50
# Epoch 50 	 Training Loss:   0.6087                               Training Acc:    0.9549
# Epoch 50 	 Validation Loss: 0.9022                               Validation Acc:  0.8410
# Not saved
# Finished Training in 1552 seconds

# %%
print("Begin Testing")
model.load_state_dict(torch.load(unpruned_path))

test_correct = 0
test_total = 0

with torch.no_grad():
  for i, data in enumerate(test_loader):
    images, labels = data
    images, labels = images.to(device), labels.to(device)

    outputs = model(images)

    _, predicted = torch.max(outputs.data, 1)
    test_total += labels.size(0)
    test_correct += (predicted == labels).sum().item()

print(f'Accuracy of unpruned network on {test_total} test images: {100 * test_correct // test_total}%')
# Out:
# Begin Testing
# Accuracy of unpruned network on 9984 test images: 82%

# %% [markdown]
# # Pruning

# %%
global_nz_param_plot = []
global_acc_plot = []
print("Begin Global Pruning")
for i in range(20):
  model.load_state_dict(torch.load(unpruned_path))
  model = prune_model_global_unstructured(model, i * 0.05)
  non_zeros = sparsity_calculation(model)
  global_nz_param_plot.append(non_zeros)

  # torch.save(model.state_dict(), f"./saved_models/test/pruned_global_weights{i*5}.pth")

  accuracy, test_total = test_model(model, test_loader)
  global_acc_plot.append(accuracy)

  print(f'Global - Accuracy of pruned network {i*5}%: {accuracy}%')
# Out:
# Begin Global Pruning
# Non-Zero Parameters: 5016563
# Total Parameters: 5016563
# Sparsity: 0.0
# Global - Accuracy of pruned network 0%: 82%
# Non-Zero Parameters: 4767937
# Total Parameters: 5016563
# Sparsity: 0.0496
# Global - Accuracy of pruned network 5%: 82%
# Non-Zero Parameters: 4519310
# Total Parameters: 5016563
# Sparsity: 0.0991
# Global - Accuracy of pruned network 10%: 82%
# Non-Zero Parameters: 4270684
# Total Parameters: 5016563
# Sparsity: 0.1487
# Global - Accuracy of pruned network 15%: 82%
# Non-Zero Parameters: 4022057
# Total Parameters: 5016563
# Sparsity: 0.1982
# Global - Accuracy of pruned network 20%: 83%
# Non-Zero Parameters: 3773431
# Total Parameters: 5016563
# Sparsity: 0.2478
# Global - Accuracy of pruned network 25%: 83%
# Non-Zero Parameters: 3524805
# Total Parameters: 5016563
# Sparsity: 0.2974
# Global - Accuracy of pruned network 30%: 82%
# Non-Zero Parameters: 3276178
# Total Parameters: 5016563
# Sparsity: 0.3469
# Global - Accuracy of pruned network 35%: 82%
# Non-Zero Parameters: 3027552
# Total Parameters: 5016563
# Sparsity: 0.3965
# Global - Accuracy of pruned network 40%: 82%
# Non-Zero Parameters: 2778925
# Total Parameters: 5016563
# Sparsity: 0.4461
# Global - Accuracy of pruned network 45%: 82%
# Non-Zero Parameters: 2530299
# Total Parameters: 5016563
# Sparsity: 0.4956
# Global - Accuracy of pruned network 50%: 82%
# Non-Zero Parameters: 2281673
# Total Parameters: 5016563
# Sparsity: 0.5452
# Global - Accuracy of pruned network 55%: 80%
# Non-Zero Parameters: 2033046
# Total Parameters: 5016563
# Sparsity: 0.5947
# Global - Accuracy of pruned network 60%: 78%
# Non-Zero Parameters: 1784420
# Total Parameters: 5016563
# Sparsity: 0.6443
# Global - Accuracy of pruned network 65%: 74%
# Non-Zero Parameters: 1535793
# Total Parameters: 5016563
# Sparsity: 0.6939
# Global - Accuracy of pruned network 70%: 62%
# Non-Zero Parameters: 1287167
# Total Parameters: 5016563
# Sparsity: 0.7434
# Global - Accuracy of pruned network 75%: 42%
# Non-Zero Parameters: 1038541
# Total Parameters: 5016563
# Sparsity: 0.793
# Global - Accuracy of pruned network 80%: 19%
# Non-Zero Parameters: 789914
# Total Parameters: 5016563
# Sparsity: 0.8425
# Global - Accuracy of pruned network 85%: 14%
# Non-Zero Parameters: 541288
# Total Parameters: 5016563
# Sparsity: 0.8921
# Global - Accuracy of pruned network 90%: 10%
# Non-Zero Parameters: 292661
# Total Parameters: 5016563
# Sparsity: 0.9417
# Global - Accuracy of pruned network 95%: 9%

# %%
struct_nz_param_plot = []
struct_acc_plot = []
print("Begin Unstructured Pruning")
for i in range(20):
  model.load_state_dict(torch.load(unpruned_path))
  model = prune_model_ln_structured(model, i * 0.05)
  non_zeros = sparsity_calculation(model)
  struct_nz_param_plot.append(non_zeros)

  # torch.save(model.state_dict(), f"./saved_models/test/pruned_struct_weights{i*5}.pth")

  accuracy, test_total = test_model(model, test_loader)
  struct_acc_plot.append(accuracy)

  print(f'Structured - Accuracy of pruned network {i*5}%: {accuracy}%')
# Out:
# Begin Unstructured Pruning
# Non-Zero Parameters: 5016563
# Total Parameters: 5016563
# Sparsity: 0.0
# Structured - Accuracy of pruned network 0%: 82%
# Non-Zero Parameters: 4767171
# Total Parameters: 5016563
# Sparsity: 0.0497
# Structured - Accuracy of pruned network 5%: 79%
# Non-Zero Parameters: 4521315
# Total Parameters: 5016563
# Sparsity: 0.0987
# Structured - Accuracy of pruned network 10%: 71%
# Non-Zero Parameters: 4272963
# Total Parameters: 5016563
# Sparsity: 0.1482
# Structured - Accuracy of pruned network 15%: 54%
# Non-Zero Parameters: 4026963
# Total Parameters: 5016563
# Sparsity: 0.1973
# Structured - Accuracy of pruned network 20%: 19%
# Non-Zero Parameters: 3777571
# Total Parameters: 5016563
# Sparsity: 0.247
# Structured - Accuracy of pruned network 25%: 10%
# Non-Zero Parameters: 3528179
# Total Parameters: 5016563
# Sparsity: 0.2967
# Structured - Accuracy of pruned network 30%: 10%
# Non-Zero Parameters: 3282323
# Total Parameters: 5016563
# Sparsity: 0.3457
# Structured - Accuracy of pruned network 35%: 10%
# Non-Zero Parameters: 3033971
# Total Parameters: 5016563
# Sparsity: 0.3952
# Structured - Accuracy of pruned network 40%: 9%
# Non-Zero Parameters: 2788115
# Total Parameters: 5016563
# Sparsity: 0.4442
# Structured - Accuracy of pruned network 45%: 9%
# Non-Zero Parameters: 2538579
# Total Parameters: 5016563
# Sparsity: 0.494
# Structured - Accuracy of pruned network 50%: 9%
# Non-Zero Parameters: 2272483
# Total Parameters: 5016563
# Sparsity: 0.547
# Structured - Accuracy of pruned network 55%: 10%
# Non-Zero Parameters: 2026627
# Total Parameters: 5016563
# Sparsity: 0.596
# Structured - Accuracy of pruned network 60%: 9%
# Non-Zero Parameters: 1778275
# Total Parameters: 5016563
# Sparsity: 0.6455
# Structured - Accuracy of pruned network 65%: 10%
# Non-Zero Parameters: 1532419
# Total Parameters: 5016563
# Sparsity: 0.6945
# Structured - Accuracy of pruned network 70%: 9%
# Non-Zero Parameters: 1283027
# Total Parameters: 5016563
# Sparsity: 0.7442
# Structured - Accuracy of pruned network 75%: 10%
# Non-Zero Parameters: 1033635
# Total Parameters: 5016563
# Sparsity: 0.794
# Structured - Accuracy of pruned network 80%: 10%
# Non-Zero Parameters: 787635
# Total Parameters: 5016563
# Sparsity: 0.843
# Structured - Accuracy of pruned network 85%: 9%
# Non-Zero Parameters: 539283
# Total Parameters: 5016563
# Sparsity: 0.8925
# Structured - Accuracy of pruned network 90%: 9%
# Non-Zero Parameters: 293427
# Total Parameters: 5016563
# Sparsity: 0.9415
# Structured - Accuracy of pruned network 95%: 10%

# %%
unstruct_nz_param_plot = []
unstruct_acc_plot = []
print("Begin Unstructured Pruning")
for i in range(20):
  model.load_state_dict(torch.load(unpruned_path))
  model = prune_model_l1_unstructured(model, i * 0.05)
  non_zeros = sparsity_calculation(model)
  unstruct_nz_param_plot.append(non_zeros)

  # torch.save(model.state_dict(), f"./saved_models/test/pruned_unstruct_weights{i*5}.pth")

  accuracy, test_total = test_model(model, test_loader)
  unstruct_acc_plot.append(accuracy)

  print(f'Unstructured - Accuracy of pruned network {i*5}%: {accuracy}%')
# Out:
# Begin Unstructured Pruning
# Non-Zero Parameters: 5016563
# Total Parameters: 5016563
# Sparsity: 0.0
# Unstructured - Accuracy of pruned network 0%: 83%
# Non-Zero Parameters: 4767430
# Total Parameters: 5016563
# Sparsity: 0.0497
# Unstructured - Accuracy of pruned network 5%: 82%
# Non-Zero Parameters: 4518307
# Total Parameters: 5016563
# Sparsity: 0.0993
# Unstructured - Accuracy of pruned network 10%: 82%
# Non-Zero Parameters: 4269167
# Total Parameters: 5016563
# Sparsity: 0.149
# Unstructured - Accuracy of pruned network 15%: 82%
# Non-Zero Parameters: 4020044
# Total Parameters: 5016563
# Sparsity: 0.1986
# Unstructured - Accuracy of pruned network 20%: 82%
# Non-Zero Parameters: 3770911
# Total Parameters: 5016563
# Sparsity: 0.2483
# Unstructured - Accuracy of pruned network 25%: 81%
# Non-Zero Parameters: 3521778
# Total Parameters: 5016563
# Sparsity: 0.298
# Unstructured - Accuracy of pruned network 30%: 78%
# Non-Zero Parameters: 3272655
# Total Parameters: 5016563
# Sparsity: 0.3476
# Unstructured - Accuracy of pruned network 35%: 71%
# Non-Zero Parameters: 3023515
# Total Parameters: 5016563
# Sparsity: 0.3973
# Unstructured - Accuracy of pruned network 40%: 62%
# Non-Zero Parameters: 2774392
# Total Parameters: 5016563
# Sparsity: 0.447
# Unstructured - Accuracy of pruned network 45%: 40%
# Non-Zero Parameters: 2525259
# Total Parameters: 5016563
# Sparsity: 0.4966
# Unstructured - Accuracy of pruned network 50%: 23%
# Non-Zero Parameters: 2276126
# Total Parameters: 5016563
# Sparsity: 0.5463
# Unstructured - Accuracy of pruned network 55%: 16%
# Non-Zero Parameters: 2027003
# Total Parameters: 5016563
# Sparsity: 0.5959
# Unstructured - Accuracy of pruned network 60%: 12%
# Non-Zero Parameters: 1777863
# Total Parameters: 5016563
# Sparsity: 0.6456
# Unstructured - Accuracy of pruned network 65%: 10%
# Non-Zero Parameters: 1528740
# Total Parameters: 5016563
# Sparsity: 0.6953
# Unstructured - Accuracy of pruned network 70%: 10%
# Non-Zero Parameters: 1279607
# Total Parameters: 5016563
# Sparsity: 0.7449
# Unstructured - Accuracy of pruned network 75%: 10%
# Non-Zero Parameters: 1030474
# Total Parameters: 5016563
# Sparsity: 0.7946
# Unstructured - Accuracy of pruned network 80%: 10%
# Non-Zero Parameters: 781351
# Total Parameters: 5016563
# Sparsity: 0.8442
# Unstructured - Accuracy of pruned network 85%: 10%
# Non-Zero Parameters: 532211
# Total Parameters: 5016563
# Sparsity: 0.8939
# Unstructured - Accuracy of pruned network 90%: 9%
# Non-Zero Parameters: 283088
# Total Parameters: 5016563
# Sparsity: 0.9436
# Unstructured - Accuracy of pruned network 95%: 10%

# %%
plot_nonzero_accuracy(global_nz_param_plot, global_acc_plot,
                      struct_nz_param_plot, struct_acc_plot,
                      unstruct_nz_param_plot, unstruct_acc_plot,
                      model_size
                      )
